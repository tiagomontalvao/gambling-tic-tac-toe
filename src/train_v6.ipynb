# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import torch
from celluloid import Camera
from collections import deque
from matplotlib import animation

from controllers.game_controller import GameController
from drl.agent import DRLAgent
from models.players.random_player import RandomPlayer
from models.players.semi_random_player import SemiRandomPlayer
from models.players.drl_player import DRLPlayer
from utils import get_reward_from_winner

# %matplotlib notebook
plt.rcParams['animation.ffmpeg_path'] = "C:\\FFmpeg\\bin\\ffmpeg"

# %%
MODEL_VERSION = 'v6'
TRAIN_MODE = 'self_play' # self_play / random
INITIAL_BID_NORMALIZER = 200 # 100 if action is relative to current coins, 200 if relative to total coins

# %%
def run_validation(players, n_episodes_validation):
    game_controller = GameController()
    validation_players = [players[0], RandomPlayer(1)]
    game_controller.load_validation(validation_players)

    # Disable train mode
    players[0].train_mode = False

    validation_scores = []
    for i in range(1, n_episodes_validation+1):
        episode_winner = game_controller.run_episode(eval_mode=True)
        validation_score = get_reward_from_winner(0, episode_winner)
        validation_scores.append(validation_score)
        game_controller.game.reset()

    # Re-enable train mode
    players[0].train_mode = True
    
    return np.mean(validation_scores)

# %%
def run_validation_semi_random(players, n_episodes_validation):
    game_controller = GameController()
    validation_players = [players[0], SemiRandomPlayer(1, game_controller.game)]
    game_controller.load_validation(validation_players)

    # Disable train mode
    players[0].train_mode = False

    validation_scores = []
    for i in range(1, n_episodes_validation+1):
        episode_winner = game_controller.run_episode(eval_mode=True)
        validation_score = get_reward_from_winner(0, episode_winner)
        validation_scores.append(validation_score)
        game_controller.game.reset()

    # Re-enable train mode
    players[0].train_mode = True
    
    return np.mean(validation_scores)

# %%
def get_critic_value(agent_critic, initial_state, bid, board_move):
    action = torch.zeros(10)
    action[0] = bid/INITIAL_BID_NORMALIZER
    action[1+board_move] = 1
    action = action.unsqueeze(0).cuda()
    return agent_critic(initial_state, action).flatten().item()

def get_all_critic_values(drl_player, initial_state):
    agent_critic = drl_player.agent.agent.critic_local
    return [[get_critic_value(agent_critic, initial_state, bid, board_move) for bid in range(101)] \
                for board_move in range(9)]

# %%
def plot_critic_values(drl_player, critic_values, fig=None, ax=None):
    if fig is None:
        fig, ax = plt.subplots(3, 3, figsize=(12, 8))
    for board_move in range(9):
        axx = ax[board_move//3, board_move%3]
        axx.set_xlabel('Bid value')
        axx.set_ylabel('Quality of move')
        axx.set_title(f'Board move {board_move}')
        axx.plot(critic_values[board_move])
    fig.tight_layout()
#     plt.savefig('test.png')

# %%
def create_animation(critic_values_by_episode, drl_player, fps=10, filename='critic_values.mp4'):
    fig, ax = plt.subplots(3, 3, figsize=(12, 8))

    camera = Camera(fig)
    initial_index = 0
    while initial_index+1<len(critic_values_by_episode) and \
            critic_values_by_episode[initial_index] == critic_values_by_episode[initial_index+1]:
        initial_index += 1

    for i in range(initial_index, len(critic_values_by_episode)):
        critic_values = critic_values_by_episode[i]
        i += 1
        plot_critic_values(drl_player, critic_values, fig, ax);
        plt.pause(0.1)
        camera.snap()

    anim = camera.animate()
    FFwriter = animation.FFMpegWriter(fps=fps)
    anim.save(filename, writer=FFwriter);

# %%
def init_train(game_controller, players, n_episodes, checkpoint_each, validate_each, n_episodes_validation,
                   model_path=None, save_critic_value_each=100, save_animation_each=1000, eps_start=1.0,
                   eps_end=0.01, eps_decay=0.999, start_epoch=1, critic_values_by_episode=None):
        game_controller.load_train(players)

        if critic_values_by_episode is None:
            critic_values_by_episode = []
        initial_state = players[0]._format_state_to_agent(game_controller.game.get_state_array()).cuda().unsqueeze(0)

        try:
            validation_scores = []
            validation_scores_window = deque(maxlen=10)
            eps = eps_start
            start = time.time()
            for i in range(start_epoch, start_epoch+n_episodes):
                game_controller.players[0].update_epsilon(eps)
                if TRAIN_MODE == 'self_play':
                    game_controller.players[1].update_epsilon(eps)

                episode_winner = game_controller.run_episode(train_mode=True)
                game_controller.game.reset()

                # Update epsilon-greedy parameter
                eps = max(eps_end, eps * eps_decay)

                if i%validate_each == 0:
                    mean_validation_score = run_validation(players, n_episodes_validation)

                    validation_scores.append(mean_validation_score)
                    validation_scores_window.append(mean_validation_score)
                    mean_validation_score_last_runs = np.mean(validation_scores_window)

                    try:
                        agent_losses = players[0].agent.get_losses()
                        actor_loss = '{:+6.3f}'.format(agent_losses['actor_losses'][-1])
                        critic_loss = '{:+6.3f}'.format(agent_losses['critic_losses'][-1])
                    except:
                        actor_loss = '------'
                        critic_loss = '------'
                    print("\rEpisode #{:4d}  |  "
                        "Val. Score: {:+5.2f}   |  "
                        "Avg. Val. Score: {:+5.2f}  |  "
                        "Epsilon: {:5.3f}\n"
                        "                  "
                        "Actor Loss: {}  |  "
                        "Critic Loss: {}     |  "
                        "Time Elapsed: {:.2f}s".format(i, mean_validation_score,
                                            mean_validation_score_last_runs, eps,
                                            actor_loss, critic_loss, time.time() - start)
                    )

                if checkpoint_each != -1 and i%checkpoint_each == 0:
                    players[0].agent.save_model(f'../checkpoints/{MODEL_VERSION}_checkpoint_episode_{i}.pt')
                    print('Checkpoint saved!')
                if save_critic_value_each != -1 and i%save_critic_value_each == 0:
                    critic_values_by_episode.append(get_all_critic_values(players[0], initial_state))
                if save_animation_each != -1 and i%save_animation_each == 0:
                    create_animation(critic_values_by_episode, players[0], filename=f'../animations/{MODEL_VERSION}_critic_values_episode_{i}.mp4')
                    print('Animation of critic values saved!')
        except KeyboardInterrupt:
            pass

        # save model after all episodes
        players[0].agent.save_model(model_path)
        print('Model saved!')

        return validation_scores, critic_values_by_episode

# %%
def plot_scores(metrics, validate_each):
    new_index = pd.RangeIndex(start=1, stop=1+len(metrics)*validate_each, step=validate_each)
    fig, ax = plt.subplots(figsize=(18,6))
    ax.plot(new_index, metrics)
    series = pd.Series(metrics)
    series.index = new_index
    series.rolling(100, 1).mean().plot(ax=ax, label='MA(100)')
    ax.set_xlabel('Episodes')
    ax.set_ylabel('Score')
    plt.show();

# %%
controller = GameController()
drl_agent = DRLAgent(
    state_size=controller.game.N*controller.game.N+2,
    bid_action_size=1,
    board_action_size=controller.game.N*controller.game.N,
    seed=None,
    checkpoint_path=f'../checkpoints/{MODEL_VERSION}_checkpoint.pt'
)

# %%
n_episodes=100000
checkpoint_each=500
validate_each=100
n_episodes_validation=10
save_critic_value_each=1000
save_animation_each=5000
eps_start = 1.0
eps_end = 0.01
eps_decay = 0.999925
players = [
    DRLPlayer(0, controller.game, drl_agent, train_mode=True),
]
if TRAIN_MODE == 'self_play':
    players.append(DRLPlayer(1, controller.game, drl_agent, train_mode=True))
else:
    players.append(RandomPlayer(1))
validation_scores, critic_values_by_episode = init_train(controller, players, model_path=f'../checkpoints/{MODEL_VERSION}_model.pt',
                    n_episodes=n_episodes, checkpoint_each=checkpoint_each, validate_each=validate_each,
                    n_episodes_validation=n_episodes_validation, save_animation_each=save_animation_each,
                    save_critic_value_each=save_critic_value_each, eps_start=eps_start, eps_end=eps_end, eps_decay=eps_decay)
# Out:
# Episode # 100  |  Val. Score: -0.80   |  Avg. Val. Score: -0.80  |  Epsilon: 0.993
#                   Actor Loss: -0.099  |  Critic Loss: +0.058     |  Time Elapsed: 48.86s
# Episode # 200  |  Val. Score: -0.40   |  Avg. Val. Score: -0.60  |  Epsilon: 0.985
#                   Actor Loss: -0.372  |  Critic Loss: +0.068     |  Time Elapsed: 175.76s
# Episode # 300  |  Val. Score: +0.10   |  Avg. Val. Score: -0.37  |  Epsilon: 0.978
#                   Actor Loss: -0.401  |  Critic Loss: +0.076     |  Time Elapsed: 307.72s
# Episode # 400  |  Val. Score: -0.20   |  Avg. Val. Score: -0.33  |  Epsilon: 0.970
#                   Actor Loss: -0.490  |  Critic Loss: +0.078     |  Time Elapsed: 428.82s
# Episode # 500  |  Val. Score: -0.30   |  Avg. Val. Score: -0.32  |  Epsilon: 0.963
#                   Actor Loss: -0.569  |  Critic Loss: +0.084     |  Time Elapsed: 542.27s
# Checkpoint saved!
# Episode # 600  |  Val. Score: -0.50   |  Avg. Val. Score: -0.35  |  Epsilon: 0.956
#                   Actor Loss: -0.664  |  Critic Loss: +0.096     |  Time Elapsed: 668.43s
# Episode # 700  |  Val. Score: -0.60   |  Avg. Val. Score: -0.39  |  Epsilon: 0.949
#                   Actor Loss: -0.707  |  Critic Loss: +0.117     |  Time Elapsed: 795.86s
# Episode # 800  |  Val. Score: +0.40   |  Avg. Val. Score: -0.29  |  Epsilon: 0.942
#                   Actor Loss: -0.819  |  Critic Loss: +0.127     |  Time Elapsed: 923.34s
# Episode # 900  |  Val. Score: -0.50   |  Avg. Val. Score: -0.31  |  Epsilon: 0.935
#                   Actor Loss: -0.865  |  Critic Loss: +0.125     |  Time Elapsed: 1052.29s
# Episode #1000  |  Val. Score: +0.30   |  Avg. Val. Score: -0.25  |  Epsilon: 0.928
#                   Actor Loss: -0.938  |  Critic Loss: +0.150     |  Time Elapsed: 1182.27s
# Checkpoint saved!
# Episode #1100  |  Val. Score: +0.00   |  Avg. Val. Score: -0.17  |  Epsilon: 0.921
#                   Actor Loss: -0.954  |  Critic Loss: +0.160     |  Time Elapsed: 1310.03s
# Episode #1200  |  Val. Score: -0.80   |  Avg. Val. Score: -0.21  |  Epsilon: 0.914
#                   Actor Loss: -1.061  |  Critic Loss: +0.177     |  Time Elapsed: 1438.83s
# Episode #1300  |  Val. Score: +0.20   |  Avg. Val. Score: -0.20  |  Epsilon: 0.907
#                   Actor Loss: -1.144  |  Critic Loss: +0.171     |  Time Elapsed: 1571.59s
# Episode #1400  |  Val. Score: -0.10   |  Avg. Val. Score: -0.19  |  Epsilon: 0.900
#                   Actor Loss: -1.163  |  Critic Loss: +0.190     |  Time Elapsed: 1705.64s
# Episode #1500  |  Val. Score: -0.20   |  Avg. Val. Score: -0.18  |  Epsilon: 0.894
#                   Actor Loss: -1.164  |  Critic Loss: +0.206     |  Time Elapsed: 1829.48s
# Checkpoint saved!
# Episode #1600  |  Val. Score: +0.40   |  Avg. Val. Score: -0.09  |  Epsilon: 0.887
#                   Actor Loss: -1.184  |  Critic Loss: +0.186     |  Time Elapsed: 1956.61s
# Episode #1700  |  Val. Score: -0.20   |  Avg. Val. Score: -0.05  |  Epsilon: 0.880
#                   Actor Loss: -1.200  |  Critic Loss: +0.217     |  Time Elapsed: 2086.35s
# Episode #1800  |  Val. Score: -0.70   |  Avg. Val. Score: -0.16  |  Epsilon: 0.874
#                   Actor Loss: -1.178  |  Critic Loss: +0.211     |  Time Elapsed: 2211.21s
# Episode #1900  |  Val. Score: -0.50   |  Avg. Val. Score: -0.16  |  Epsilon: 0.867
#                   Actor Loss: -1.160  |  Critic Loss: +0.240     |  Time Elapsed: 2331.63s
# Episode #2000  |  Val. Score: -0.40   |  Avg. Val. Score: -0.23  |  Epsilon: 0.861
#                   Actor Loss: -1.284  |  Critic Loss: +0.214     |  Time Elapsed: 2456.06s
# Checkpoint saved!
# Episode #2100  |  Val. Score: +0.20   |  Avg. Val. Score: -0.21  |  Epsilon: 0.854
#                   Actor Loss: -1.272  |  Critic Loss: +0.243     |  Time Elapsed: 2592.52s
# Episode #2200  |  Val. Score: +0.20   |  Avg. Val. Score: -0.11  |  Epsilon: 0.848
#                   Actor Loss: -1.236  |  Critic Loss: +0.207     |  Time Elapsed: 2727.61s
# Episode #2300  |  Val. Score: +0.30   |  Avg. Val. Score: -0.10  |  Epsilon: 0.842
#                   Actor Loss: -1.182  |  Critic Loss: +0.253     |  Time Elapsed: 2863.46s
# Episode #2400  |  Val. Score: +0.00   |  Avg. Val. Score: -0.09  |  Epsilon: 0.835
#                   Actor Loss: -1.161  |  Critic Loss: +0.208     |  Time Elapsed: 3001.30s
# Episode #2500  |  Val. Score: -0.30   |  Avg. Val. Score: -0.10  |  Epsilon: 0.829
#                   Actor Loss: -1.195  |  Critic Loss: +0.183     |  Time Elapsed: 3131.75s
# Checkpoint saved!
# Episode #2600  |  Val. Score: -0.50   |  Avg. Val. Score: -0.19  |  Epsilon: 0.823
#                   Actor Loss: -1.169  |  Critic Loss: +0.190     |  Time Elapsed: 3263.46s
# Episode #2700  |  Val. Score: -0.40   |  Avg. Val. Score: -0.21  |  Epsilon: 0.817
#                   Actor Loss: -1.168  |  Critic Loss: +0.201     |  Time Elapsed: 3390.01s
# Episode #2800  |  Val. Score: -0.30   |  Avg. Val. Score: -0.17  |  Epsilon: 0.811
#                   Actor Loss: -1.168  |  Critic Loss: +0.179     |  Time Elapsed: 3513.85s
# Episode #2900  |  Val. Score: +0.20   |  Avg. Val. Score: -0.10  |  Epsilon: 0.805
#                   Actor Loss: -1.215  |  Critic Loss: +0.219     |  Time Elapsed: 3640.86s
# Episode #3000  |  Val. Score: +0.30   |  Avg. Val. Score: -0.03  |  Epsilon: 0.799
#                   Actor Loss: -1.208  |  Critic Loss: +0.231     |  Time Elapsed: 3769.44s
# Checkpoint saved!
# Episode #3100  |  Val. Score: -0.20   |  Avg. Val. Score: -0.07  |  Epsilon: 0.793
#                   Actor Loss: -1.235  |  Critic Loss: +0.185     |  Time Elapsed: 3886.83s
# Episode #3200  |  Val. Score: -0.50   |  Avg. Val. Score: -0.14  |  Epsilon: 0.787
#                   Actor Loss: -1.195  |  Critic Loss: +0.211     |  Time Elapsed: 4012.24s
# Episode #3300  |  Val. Score: +0.60   |  Avg. Val. Score: -0.11  |  Epsilon: 0.781
#                   Actor Loss: -1.166  |  Critic Loss: +0.220     |  Time Elapsed: 4144.69s
# Episode #3400  |  Val. Score: -0.40   |  Avg. Val. Score: -0.15  |  Epsilon: 0.775
#                   Actor Loss: -1.175  |  Critic Loss: +0.184     |  Time Elapsed: 4279.01s
# Episode #3500  |  Val. Score: -0.40   |  Avg. Val. Score: -0.16  |  Epsilon: 0.769
#                   Actor Loss: -1.152  |  Critic Loss: +0.175     |  Time Elapsed: 4405.70s
# Checkpoint saved!
# Episode #3600  |  Val. Score: +0.10   |  Avg. Val. Score: -0.10  |  Epsilon: 0.763
#                   Actor Loss: -1.117  |  Critic Loss: +0.214     |  Time Elapsed: 4533.79s
# Episode #3700  |  Val. Score: -0.30   |  Avg. Val. Score: -0.09  |  Epsilon: 0.758
#                   Actor Loss: -1.120  |  Critic Loss: +0.176     |  Time Elapsed: 4667.45s
# Episode #3800  |  Val. Score: -0.20   |  Avg. Val. Score: -0.08  |  Epsilon: 0.752
#                   Actor Loss: -1.125  |  Critic Loss: +0.180     |  Time Elapsed: 4795.08s
# Episode #3900  |  Val. Score: +0.10   |  Avg. Val. Score: -0.09  |  Epsilon: 0.746
#                   Actor Loss: -1.134  |  Critic Loss: +0.191     |  Time Elapsed: 4922.40s
# Episode #4000  |  Val. Score: +0.20   |  Avg. Val. Score: -0.10  |  Epsilon: 0.741
#                   Actor Loss: -1.136  |  Critic Loss: +0.202     |  Time Elapsed: 5037.90s
# Checkpoint saved!
# Episode #4100  |  Val. Score: +0.50   |  Avg. Val. Score: -0.03  |  Epsilon: 0.735
#                   Actor Loss: -1.115  |  Critic Loss: +0.181     |  Time Elapsed: 5149.43s
# Episode #4200  |  Val. Score: -0.20   |  Avg. Val. Score: -0.00  |  Epsilon: 0.730
#                   Actor Loss: -1.133  |  Critic Loss: +0.177     |  Time Elapsed: 5256.88s
# Episode #4300  |  Val. Score: -0.10   |  Avg. Val. Score: -0.07  |  Epsilon: 0.724
#                   Actor Loss: -1.106  |  Critic Loss: +0.175     |  Time Elapsed: 5367.45s
# Episode #4400  |  Val. Score: +0.10   |  Avg. Val. Score: -0.02  |  Epsilon: 0.719
#                   Actor Loss: -1.116  |  Critic Loss: +0.178     |  Time Elapsed: 5480.37s
# Episode #4500  |  Val. Score: -0.20   |  Avg. Val. Score: -0.00  |  Epsilon: 0.714
#                   Actor Loss: -1.118  |  Critic Loss: +0.183     |  Time Elapsed: 5590.87s
# Checkpoint saved!
# Episode #4600  |  Val. Score: +0.30   |  Avg. Val. Score: +0.02  |  Epsilon: 0.708
#                   Actor Loss: -1.089  |  Critic Loss: +0.189     |  Time Elapsed: 5704.08s
# Episode #4700  |  Val. Score: +0.30   |  Avg. Val. Score: +0.08  |  Epsilon: 0.703
#                   Actor Loss: -1.097  |  Critic Loss: +0.165     |  Time Elapsed: 5816.80s
# Episode #4800  |  Val. Score: -0.40   |  Avg. Val. Score: +0.06  |  Epsilon: 0.698
#                   Actor Loss: -1.078  |  Critic Loss: +0.177     |  Time Elapsed: 5930.55s
# Episode #4900  |  Val. Score: +0.50   |  Avg. Val. Score: +0.10  |  Epsilon: 0.692
#                   Actor Loss: -1.086  |  Critic Loss: +0.166     |  Time Elapsed: 6042.71s
# Episode #5000  |  Val. Score: +0.10   |  Avg. Val. Score: +0.09  |  Epsilon: 0.687
#                   Actor Loss: -1.103  |  Critic Loss: +0.216     |  Time Elapsed: 6152.94s
# Checkpoint saved!
# Animation of critic values saved!
# Episode #5100  |  Val. Score: -0.20   |  Avg. Val. Score: +0.02  |  Epsilon: 0.682
#                   Actor Loss: -1.115  |  Critic Loss: +0.179     |  Time Elapsed: 6266.88s
# Episode #5200  |  Val. Score: -0.20   |  Avg. Val. Score: +0.02  |  Epsilon: 0.677
#                   Actor Loss: -1.122  |  Critic Loss: +0.192     |  Time Elapsed: 6375.75s
# Episode #5300  |  Val. Score: -0.60   |  Avg. Val. Score: -0.03  |  Epsilon: 0.672
#                   Actor Loss: -1.100  |  Critic Loss: +0.202     |  Time Elapsed: 6493.31s
# Episode #5400  |  Val. Score: -0.20   |  Avg. Val. Score: -0.06  |  Epsilon: 0.667
#                   Actor Loss: -1.108  |  Critic Loss: +0.186     |  Time Elapsed: 6606.86s
# Episode #5500  |  Val. Score: -0.10   |  Avg. Val. Score: -0.05  |  Epsilon: 0.662
#                   Actor Loss: -1.084  |  Critic Loss: +0.178     |  Time Elapsed: 6720.05s
# Checkpoint saved!
# Episode #5600  |  Val. Score: -0.30   |  Avg. Val. Score: -0.11  |  Epsilon: 0.657
#                   Actor Loss: -1.071  |  Critic Loss: +0.170     |  Time Elapsed: 6831.35s
# Episode #5700  |  Val. Score: +0.00   |  Avg. Val. Score: -0.14  |  Epsilon: 0.652
#                   Actor Loss: -1.070  |  Critic Loss: +0.170     |  Time Elapsed: 6939.76s
# Episode #5800  |  Val. Score: -0.20   |  Avg. Val. Score: -0.12  |  Epsilon: 0.647
#                   Actor Loss: -1.051  |  Critic Loss: +0.189     |  Time Elapsed: 7045.91s
# Episode #5900  |  Val. Score: +0.00   |  Avg. Val. Score: -0.17  |  Epsilon: 0.642
#                   Actor Loss: -1.019  |  Critic Loss: +0.174     |  Time Elapsed: 7152.64s
# Episode #6000  |  Val. Score: +0.70   |  Avg. Val. Score: -0.11  |  Epsilon: 0.638
#                   Actor Loss: -1.014  |  Critic Loss: +0.175     |  Time Elapsed: 7259.54s
# Checkpoint saved!
# Episode #6100  |  Val. Score: +0.70   |  Avg. Val. Score: -0.02  |  Epsilon: 0.633
#                   Actor Loss: -1.011  |  Critic Loss: +0.157     |  Time Elapsed: 7366.46s
# Episode #6200  |  Val. Score: +0.20   |  Avg. Val. Score: +0.02  |  Epsilon: 0.628
#                   Actor Loss: -0.998  |  Critic Loss: +0.163     |  Time Elapsed: 7469.49s
# Episode #6300  |  Val. Score: +0.10   |  Avg. Val. Score: +0.09  |  Epsilon: 0.623
#                   Actor Loss: -0.995  |  Critic Loss: +0.167     |  Time Elapsed: 7572.89s
# Episode #6400  |  Val. Score: -0.20   |  Avg. Val. Score: +0.09  |  Epsilon: 0.619
#                   Actor Loss: -0.965  |  Critic Loss: +0.163     |  Time Elapsed: 7680.76s
# Episode #6500  |  Val. Score: +0.00   |  Avg. Val. Score: +0.10  |  Epsilon: 0.614
#                   Actor Loss: -1.011  |  Critic Loss: +0.135     |  Time Elapsed: 7790.85s
# Checkpoint saved!
# Episode #6600  |  Val. Score: -0.50   |  Avg. Val. Score: +0.08  |  Epsilon: 0.610
#                   Actor Loss: -0.966  |  Critic Loss: +0.183     |  Time Elapsed: 7895.45s
# Episode #6700  |  Val. Score: -0.20   |  Avg. Val. Score: +0.06  |  Epsilon: 0.605
#                   Actor Loss: -1.000  |  Critic Loss: +0.143     |  Time Elapsed: 8002.56s
# Episode #6800  |  Val. Score: +0.40   |  Avg. Val. Score: +0.12  |  Epsilon: 0.600
#                   Actor Loss: -0.979  |  Critic Loss: +0.165     |  Time Elapsed: 8106.90s
# Episode #6900  |  Val. Score: +0.10   |  Avg. Val. Score: +0.13  |  Epsilon: 0.596
#                   Actor Loss: -0.970  |  Critic Loss: +0.158     |  Time Elapsed: 8214.67s
# Episode #7000  |  Val. Score: +0.10   |  Avg. Val. Score: +0.07  |  Epsilon: 0.592
#                   Actor Loss: -0.972  |  Critic Loss: +0.159     |  Time Elapsed: 8319.16s
# Checkpoint saved!
# Episode #7100  |  Val. Score: -0.30   |  Avg. Val. Score: -0.03  |  Epsilon: 0.587
#                   Actor Loss: -0.980  |  Critic Loss: +0.167     |  Time Elapsed: 8422.31s
# Episode #7200  |  Val. Score: +0.30   |  Avg. Val. Score: -0.02  |  Epsilon: 0.583
#                   Actor Loss: -0.982  |  Critic Loss: +0.163     |  Time Elapsed: 8531.88s
# Episode #7300  |  Val. Score: +0.20   |  Avg. Val. Score: -0.01  |  Epsilon: 0.578
#                   Actor Loss: -0.983  |  Critic Loss: +0.174     |  Time Elapsed: 8643.41s
# Episode #7400  |  Val. Score: +0.50   |  Avg. Val. Score: +0.06  |  Epsilon: 0.574
#                   Actor Loss: -0.979  |  Critic Loss: +0.169     |  Time Elapsed: 8752.17s
# Episode #7500  |  Val. Score: -0.50   |  Avg. Val. Score: +0.01  |  Epsilon: 0.570
#                   Actor Loss: -0.993  |  Critic Loss: +0.157     |  Time Elapsed: 8859.44s
# Checkpoint saved!
# Episode #7600  |  Val. Score: +0.10   |  Avg. Val. Score: +0.07  |  Epsilon: 0.566
#                   Actor Loss: -0.996  |  Critic Loss: +0.156     |  Time Elapsed: 8966.14s
# Episode #7700  |  Val. Score: -0.20   |  Avg. Val. Score: +0.07  |  Epsilon: 0.561
#                   Actor Loss: -0.969  |  Critic Loss: +0.153     |  Time Elapsed: 9076.94s
# Episode #7800  |  Val. Score: +0.30   |  Avg. Val. Score: +0.06  |  Epsilon: 0.557
#                   Actor Loss: -0.942  |  Critic Loss: +0.171     |  Time Elapsed: 9181.78s
# Episode #7900  |  Val. Score: +0.00   |  Avg. Val. Score: +0.05  |  Epsilon: 0.553
#                   Actor Loss: -0.925  |  Critic Loss: +0.155     |  Time Elapsed: 9288.79s
# Episode #8000  |  Val. Score: +0.00   |  Avg. Val. Score: +0.04  |  Epsilon: 0.549
#                   Actor Loss: -0.921  |  Critic Loss: +0.149     |  Time Elapsed: 9396.06s
# Checkpoint saved!
# Episode #8100  |  Val. Score: +0.00   |  Avg. Val. Score: +0.07  |  Epsilon: 0.545
#                   Actor Loss: -0.907  |  Critic Loss: +0.153     |  Time Elapsed: 9503.67s
# Episode #8200  |  Val. Score: +0.30   |  Avg. Val. Score: +0.07  |  Epsilon: 0.541
#                   Actor Loss: -0.928  |  Critic Loss: +0.160     |  Time Elapsed: 9610.40s
# Episode #8300  |  Val. Score: +0.30   |  Avg. Val. Score: +0.08  |  Epsilon: 0.537
#                   Actor Loss: -0.902  |  Critic Loss: +0.147     |  Time Elapsed: 9716.04s
# Episode #8400  |  Val. Score: +0.10   |  Avg. Val. Score: +0.04  |  Epsilon: 0.533
#                   Actor Loss: -0.924  |  Critic Loss: +0.132     |  Time Elapsed: 9822.26s
# Episode #8500  |  Val. Score: -0.10   |  Avg. Val. Score: +0.08  |  Epsilon: 0.529
#                   Actor Loss: -0.898  |  Critic Loss: +0.134     |  Time Elapsed: 9928.92s
# Checkpoint saved!
# Episode #8600  |  Val. Score: +0.20   |  Avg. Val. Score: +0.09  |  Epsilon: 0.525
#                   Actor Loss: -0.890  |  Critic Loss: +0.149     |  Time Elapsed: 10037.97s
# Episode #8700  |  Val. Score: +0.30   |  Avg. Val. Score: +0.14  |  Epsilon: 0.521
#                   Actor Loss: -0.887  |  Critic Loss: +0.151     |  Time Elapsed: 10146.60s
# Episode #8800  |  Val. Score: +0.20   |  Avg. Val. Score: +0.13  |  Epsilon: 0.517
#                   Actor Loss: -0.900  |  Critic Loss: +0.134     |  Time Elapsed: 10251.85s
# Episode #8900  |  Val. Score: +0.80   |  Avg. Val. Score: +0.21  |  Epsilon: 0.513
#                   Actor Loss: -0.907  |  Critic Loss: +0.131     |  Time Elapsed: 10357.17s
# Episode #9000  |  Val. Score: +0.20   |  Avg. Val. Score: +0.23  |  Epsilon: 0.509
#                   Actor Loss: -0.907  |  Critic Loss: +0.118     |  Time Elapsed: 10468.57s
# Checkpoint saved!
# Episode #9100  |  Val. Score: -0.30   |  Avg. Val. Score: +0.20  |  Epsilon: 0.505
#                   Actor Loss: -0.889  |  Critic Loss: +0.123     |  Time Elapsed: 10578.70s
# Episode #9200  |  Val. Score: -0.20   |  Avg. Val. Score: +0.15  |  Epsilon: 0.502
#                   Actor Loss: -0.874  |  Critic Loss: +0.136     |  Time Elapsed: 10688.76s
# Episode #9300  |  Val. Score: +0.10   |  Avg. Val. Score: +0.13  |  Epsilon: 0.498
#                   Actor Loss: -0.871  |  Critic Loss: +0.153     |  Time Elapsed: 10798.81s
# Episode #9400  |  Val. Score: -0.30   |  Avg. Val. Score: +0.09  |  Epsilon: 0.494
#                   Actor Loss: -0.887  |  Critic Loss: +0.154     |  Time Elapsed: 10909.32s
# Episode #9500  |  Val. Score: +0.90   |  Avg. Val. Score: +0.19  |  Epsilon: 0.490
#                   Actor Loss: -0.871  |  Critic Loss: +0.142     |  Time Elapsed: 11019.81s
# Checkpoint saved!
# Episode #9600  |  Val. Score: -0.10   |  Avg. Val. Score: +0.16  |  Epsilon: 0.487
#                   Actor Loss: -0.915  |  Critic Loss: +0.162     |  Time Elapsed: 11130.85s
# Episode #9700  |  Val. Score: -0.10   |  Avg. Val. Score: +0.12  |  Epsilon: 0.483
#                   Actor Loss: -0.909  |  Critic Loss: +0.157     |  Time Elapsed: 11234.76s
# Episode #9800  |  Val. Score: -0.50   |  Avg. Val. Score: +0.05  |  Epsilon: 0.479
#                   Actor Loss: -0.875  |  Critic Loss: +0.165     |  Time Elapsed: 11337.65s
# Episode #9900  |  Val. Score: -0.20   |  Avg. Val. Score: -0.05  |  Epsilon: 0.476
#                   Actor Loss: -0.888  |  Critic Loss: +0.160     |  Time Elapsed: 11446.51s
# Episode #10000  |  Val. Score: +0.30   |  Avg. Val. Score: -0.04  |  Epsilon: 0.472
#                   Actor Loss: -0.900  |  Critic Loss: +0.169     |  Time Elapsed: 11557.89s
# Checkpoint saved!
# Animation of critic values saved!
# Episode #10100  |  Val. Score: +0.20   |  Avg. Val. Score: +0.01  |  Epsilon: 0.469
#                   Actor Loss: -0.897  |  Critic Loss: +0.152     |  Time Elapsed: 11677.25s
# Episode #10200  |  Val. Score: +0.80   |  Avg. Val. Score: +0.11  |  Epsilon: 0.465
#                   Actor Loss: -0.890  |  Critic Loss: +0.145     |  Time Elapsed: 11786.40s
# Episode #10300  |  Val. Score: +0.20   |  Avg. Val. Score: +0.12  |  Epsilon: 0.462
#                   Actor Loss: -0.876  |  Critic Loss: +0.158     |  Time Elapsed: 11895.10s
# Episode #10400  |  Val. Score: -0.30   |  Avg. Val. Score: +0.12  |  Epsilon: 0.458
#                   Actor Loss: -0.890  |  Critic Loss: +0.152     |  Time Elapsed: 12002.53s
# Episode #10500  |  Val. Score: +0.60   |  Avg. Val. Score: +0.09  |  Epsilon: 0.455
#                   Actor Loss: -0.867  |  Critic Loss: +0.155     |  Time Elapsed: 12111.82s
# Checkpoint saved!
# Episode #10600  |  Val. Score: +0.20   |  Avg. Val. Score: +0.12  |  Epsilon: 0.452
#                   Actor Loss: -0.894  |  Critic Loss: +0.119     |  Time Elapsed: 12218.75s
# Episode #10700  |  Val. Score: -0.40   |  Avg. Val. Score: +0.09  |  Epsilon: 0.448
#                   Actor Loss: -0.853  |  Critic Loss: +0.145     |  Time Elapsed: 12328.30s
# Episode #10800  |  Val. Score: +0.00   |  Avg. Val. Score: +0.14  |  Epsilon: 0.445
#                   Actor Loss: -0.881  |  Critic Loss: +0.125     |  Time Elapsed: 12434.95s
# Episode #10900  |  Val. Score: +0.10   |  Avg. Val. Score: +0.17  |  Epsilon: 0.442
#                   Actor Loss: -0.832  |  Critic Loss: +0.137     |  Time Elapsed: 12542.28s
# Episode #11000  |  Val. Score: -0.20   |  Avg. Val. Score: +0.12  |  Epsilon: 0.438
#                   Actor Loss: -0.824  |  Critic Loss: +0.139     |  Time Elapsed: 12650.77s
# Checkpoint saved!
# Episode #11100  |  Val. Score: -0.20   |  Avg. Val. Score: +0.08  |  Epsilon: 0.435
#                   Actor Loss: -0.815  |  Critic Loss: +0.125     |  Time Elapsed: 12760.70s
# Episode #11200  |  Val. Score: -0.20   |  Avg. Val. Score: -0.02  |  Epsilon: 0.432
#                   Actor Loss: -0.791  |  Critic Loss: +0.145     |  Time Elapsed: 12871.30s
# Episode #11300  |  Val. Score: +0.00   |  Avg. Val. Score: -0.04  |  Epsilon: 0.428
#                   Actor Loss: -0.781  |  Critic Loss: +0.139     |  Time Elapsed: 12981.03s
# Episode #11400  |  Val. Score: -0.20   |  Avg. Val. Score: -0.03  |  Epsilon: 0.425
#                   Actor Loss: -0.800  |  Critic Loss: +0.125     |  Time Elapsed: 13088.67s
# Episode #11500  |  Val. Score: -0.10   |  Avg. Val. Score: -0.10  |  Epsilon: 0.422
#                   Actor Loss: -0.772  |  Critic Loss: +0.118     |  Time Elapsed: 13196.75s
# Checkpoint saved!
# Episode #11600  |  Val. Score: +0.30   |  Avg. Val. Score: -0.09  |  Epsilon: 0.419
#                   Actor Loss: -0.754  |  Critic Loss: +0.129     |  Time Elapsed: 13305.86s
# Episode #11700  |  Val. Score: +0.20   |  Avg. Val. Score: -0.03  |  Epsilon: 0.416
#                   Actor Loss: -0.782  |  Critic Loss: +0.118     |  Time Elapsed: 13414.88s
# Episode #11800  |  Val. Score: -0.10   |  Avg. Val. Score: -0.04  |  Epsilon: 0.413
#                   Actor Loss: -0.761  |  Critic Loss: +0.137     |  Time Elapsed: 13531.91s
# Episode #11900  |  Val. Score: +0.00   |  Avg. Val. Score: -0.05  |  Epsilon: 0.410
#                   Actor Loss: -0.776  |  Critic Loss: +0.141     |  Time Elapsed: 13648.22s
# Episode #12000  |  Val. Score: +0.60   |  Avg. Val. Score: +0.03  |  Epsilon: 0.407
#                   Actor Loss: -0.779  |  Critic Loss: +0.147     |  Time Elapsed: 13761.51s
# Checkpoint saved!
# Episode #12100  |  Val. Score: -0.30   |  Avg. Val. Score: +0.02  |  Epsilon: 0.404
#                   Actor Loss: -0.828  |  Critic Loss: +0.138     |  Time Elapsed: 13877.97s
# Episode #12200  |  Val. Score: -0.20   |  Avg. Val. Score: +0.02  |  Epsilon: 0.401
#                   Actor Loss: -0.821  |  Critic Loss: +0.142     |  Time Elapsed: 13989.32s
# Episode #12300  |  Val. Score: -0.30   |  Avg. Val. Score: -0.01  |  Epsilon: 0.398
#                   Actor Loss: -0.802  |  Critic Loss: +0.138     |  Time Elapsed: 14100.33s
# Episode #12400  |  Val. Score: -0.40   |  Avg. Val. Score: -0.03  |  Epsilon: 0.395
#                   Actor Loss: -0.795  |  Critic Loss: +0.124     |  Time Elapsed: 14211.01s
# Episode #12500  |  Val. Score: -0.50   |  Avg. Val. Score: -0.07  |  Epsilon: 0.392
#                   Actor Loss: -0.788  |  Critic Loss: +0.141     |  Time Elapsed: 14317.28s
# Checkpoint saved!
# Episode #12600  |  Val. Score: -0.30   |  Avg. Val. Score: -0.13  |  Epsilon: 0.389
#                   Actor Loss: -0.801  |  Critic Loss: +0.141     |  Time Elapsed: 14428.10s
# Episode #12700  |  Val. Score: +0.30   |  Avg. Val. Score: -0.12  |  Epsilon: 0.386
#                   Actor Loss: -0.801  |  Critic Loss: +0.163     |  Time Elapsed: 14542.43s
# Episode #12800  |  Val. Score: +0.50   |  Avg. Val. Score: -0.06  |  Epsilon: 0.383
#                   Actor Loss: -0.806  |  Critic Loss: +0.125     |  Time Elapsed: 14652.78s
# Episode #12900  |  Val. Score: +0.40   |  Avg. Val. Score: -0.02  |  Epsilon: 0.380
#                   Actor Loss: -0.786  |  Critic Loss: +0.139     |  Time Elapsed: 14764.82s
# Episode #13000  |  Val. Score: +0.30   |  Avg. Val. Score: -0.05  |  Epsilon: 0.377
#                   Actor Loss: -0.790  |  Critic Loss: +0.133     |  Time Elapsed: 14878.44s
# Checkpoint saved!
# Episode #13100  |  Val. Score: +0.00   |  Avg. Val. Score: -0.02  |  Epsilon: 0.374
#                   Actor Loss: -0.817  |  Critic Loss: +0.130     |  Time Elapsed: 14990.49s
# Episode #13200  |  Val. Score: -0.40   |  Avg. Val. Score: -0.04  |  Epsilon: 0.372
#                   Actor Loss: -0.798  |  Critic Loss: +0.132     |  Time Elapsed: 15102.02s
# Episode #13300  |  Val. Score: +0.00   |  Avg. Val. Score: -0.01  |  Epsilon: 0.369
#                   Actor Loss: -0.776  |  Critic Loss: +0.118     |  Time Elapsed: 15213.00s
# Episode #13400  |  Val. Score: +0.40   |  Avg. Val. Score: +0.07  |  Epsilon: 0.366
#                   Actor Loss: -0.765  |  Critic Loss: +0.118     |  Time Elapsed: 15327.17s
# Episode #13500  |  Val. Score: +0.80   |  Avg. Val. Score: +0.20  |  Epsilon: 0.363
#                   Actor Loss: -0.750  |  Critic Loss: +0.143     |  Time Elapsed: 15437.45s
# Checkpoint saved!
# Episode #13600  |  Val. Score: +0.60   |  Avg. Val. Score: +0.29  |  Epsilon: 0.361
#                   Actor Loss: -0.782  |  Critic Loss: +0.136     |  Time Elapsed: 15550.16s
# Episode #13700  |  Val. Score: +0.50   |  Avg. Val. Score: +0.31  |  Epsilon: 0.358
#                   Actor Loss: -0.754  |  Critic Loss: +0.125     |  Time Elapsed: 15662.94s
# Episode #13800  |  Val. Score: +0.50   |  Avg. Val. Score: +0.31  |  Epsilon: 0.355
#                   Actor Loss: -0.744  |  Critic Loss: +0.133     |  Time Elapsed: 15775.62s
# Episode #13900  |  Val. Score: +0.30   |  Avg. Val. Score: +0.30  |  Epsilon: 0.353
#                   Actor Loss: -0.750  |  Critic Loss: +0.121     |  Time Elapsed: 15892.13s
# Episode #14000  |  Val. Score: +0.40   |  Avg. Val. Score: +0.31  |  Epsilon: 0.350
#                   Actor Loss: -0.719  |  Critic Loss: +0.138     |  Time Elapsed: 16005.67s
# Checkpoint saved!
# Episode #14100  |  Val. Score: +0.40   |  Avg. Val. Score: +0.35  |  Epsilon: 0.347
#                   Actor Loss: -0.755  |  Critic Loss: +0.125     |  Time Elapsed: 16119.57s
# Episode #14200  |  Val. Score: +0.50   |  Avg. Val. Score: +0.44  |  Epsilon: 0.345
#                   Actor Loss: -0.725  |  Critic Loss: +0.139     |  Time Elapsed: 16230.28s
# Episode #14300  |  Val. Score: +0.60   |  Avg. Val. Score: +0.50  |  Epsilon: 0.342
#                   Actor Loss: -0.769  |  Critic Loss: +0.128     |  Time Elapsed: 16339.67s
# Episode #14400  |  Val. Score: +0.30   |  Avg. Val. Score: +0.49  |  Epsilon: 0.340
#                   Actor Loss: -0.728  |  Critic Loss: +0.130     |  Time Elapsed: 16451.43s
# Episode #14500  |  Val. Score: +0.40   |  Avg. Val. Score: +0.45  |  Epsilon: 0.337
#                   Actor Loss: -0.717  |  Critic Loss: +0.131     |  Time Elapsed: 16562.18s
# Checkpoint saved!
# Episode #14600  |  Val. Score: +0.20   |  Avg. Val. Score: +0.41  |  Epsilon: 0.335
#                   Actor Loss: -0.734  |  Critic Loss: +0.120     |  Time Elapsed: 16674.07s
# Episode #14700  |  Val. Score: +0.00   |  Avg. Val. Score: +0.36  |  Epsilon: 0.332
#                   Actor Loss: -0.702  |  Critic Loss: +0.134     |  Time Elapsed: 16788.25s
# Episode #14800  |  Val. Score: +0.00   |  Avg. Val. Score: +0.31  |  Epsilon: 0.330
#                   Actor Loss: -0.701  |  Critic Loss: +0.123     |  Time Elapsed: 16898.98s
# Episode #14900  |  Val. Score: -0.30   |  Avg. Val. Score: +0.25  |  Epsilon: 0.327
#                   Actor Loss: -0.666  |  Critic Loss: +0.126     |  Time Elapsed: 17010.36s
# Episode #15000  |  Val. Score: +0.70   |  Avg. Val. Score: +0.28  |  Epsilon: 0.325
#                   Actor Loss: -0.669  |  Critic Loss: +0.119     |  Time Elapsed: 17127.30s
# Checkpoint saved!
# Animation of critic values saved!
# Episode #15100  |  Val. Score: +0.50   |  Avg. Val. Score: +0.29  |  Epsilon: 0.322
#                   Actor Loss: -0.701  |  Critic Loss: +0.123     |  Time Elapsed: 17254.20s
# Episode #15200  |  Val. Score: -0.10   |  Avg. Val. Score: +0.23  |  Epsilon: 0.320
#                   Actor Loss: -0.725  |  Critic Loss: +0.129     |  Time Elapsed: 17364.27s
# Episode #15300  |  Val. Score: +0.30   |  Avg. Val. Score: +0.20  |  Epsilon: 0.317
#                   Actor Loss: -0.707  |  Critic Loss: +0.140     |  Time Elapsed: 17470.45s
# Episode #15400  |  Val. Score: +0.60   |  Avg. Val. Score: +0.23  |  Epsilon: 0.315
#                   Actor Loss: -0.738  |  Critic Loss: +0.120     |  Time Elapsed: 17577.31s
# Episode #15500  |  Val. Score: +0.30   |  Avg. Val. Score: +0.22  |  Epsilon: 0.313
#                   Actor Loss: -0.742  |  Critic Loss: +0.111     |  Time Elapsed: 17684.58s
# Checkpoint saved!
# Episode #15600  |  Val. Score: +0.10   |  Avg. Val. Score: +0.21  |  Epsilon: 0.310
#                   Actor Loss: -0.727  |  Critic Loss: +0.117     |  Time Elapsed: 17793.31s
# Episode #15700  |  Val. Score: +0.10   |  Avg. Val. Score: +0.22  |  Epsilon: 0.308
#                   Actor Loss: -0.754  |  Critic Loss: +0.121     |  Time Elapsed: 17907.32s
# Episode #15800  |  Val. Score: +0.00   |  Avg. Val. Score: +0.22  |  Epsilon: 0.306
#                   Actor Loss: -0.712  |  Critic Loss: +0.126     |  Time Elapsed: 18025.81s
# Episode #15900  |  Val. Score: -0.30   |  Avg. Val. Score: +0.22  |  Epsilon: 0.303
#                   Actor Loss: -0.711  |  Critic Loss: +0.135     |  Time Elapsed: 18137.37s
# Episode #16000  |  Val. Score: +0.00   |  Avg. Val. Score: +0.15  |  Epsilon: 0.301
#                   Actor Loss: -0.717  |  Critic Loss: +0.121     |  Time Elapsed: 18247.87s
# Checkpoint saved!
# Episode #16100  |  Val. Score: +0.10   |  Avg. Val. Score: +0.11  |  Epsilon: 0.299
#                   Actor Loss: -0.703  |  Critic Loss: +0.136     |  Time Elapsed: 18354.84s
# Episode #16200  |  Val. Score: +0.00   |  Avg. Val. Score: +0.12  |  Epsilon: 0.297
#                   Actor Loss: -0.702  |  Critic Loss: +0.117     |  Time Elapsed: 18467.39s
# Episode #16300  |  Val. Score: -0.30   |  Avg. Val. Score: +0.06  |  Epsilon: 0.294
#                   Actor Loss: -0.683  |  Critic Loss: +0.140     |  Time Elapsed: 18579.24s
# Episode #16400  |  Val. Score: +0.40   |  Avg. Val. Score: +0.04  |  Epsilon: 0.292
#                   Actor Loss: -0.711  |  Critic Loss: +0.116     |  Time Elapsed: 18691.03s
# Episode #16500  |  Val. Score: +0.20   |  Avg. Val. Score: +0.03  |  Epsilon: 0.290
#                   Actor Loss: -0.695  |  Critic Loss: +0.123     |  Time Elapsed: 18800.04s
# Checkpoint saved!
# Episode #16600  |  Val. Score: +0.00   |  Avg. Val. Score: +0.02  |  Epsilon: 0.288
#                   Actor Loss: -0.690  |  Critic Loss: +0.131     |  Time Elapsed: 18912.65s
# Episode #16700  |  Val. Score: +0.30   |  Avg. Val. Score: +0.04  |  Epsilon: 0.286
#                   Actor Loss: -0.676  |  Critic Loss: +0.128     |  Time Elapsed: 19024.97s
# Episode #16800  |  Val. Score: +0.30   |  Avg. Val. Score: +0.07  |  Epsilon: 0.284
#                   Actor Loss: -0.681  |  Critic Loss: +0.119     |  Time Elapsed: 19141.87s
# Episode #16900  |  Val. Score: +0.50   |  Avg. Val. Score: +0.15  |  Epsilon: 0.282
#                   Actor Loss: -0.662  |  Critic Loss: +0.119     |  Time Elapsed: 19255.25s
# Episode #17000  |  Val. Score: -0.20   |  Avg. Val. Score: +0.13  |  Epsilon: 0.279
#                   Actor Loss: -0.775  |  Critic Loss: +0.157     |  Time Elapsed: 19373.06s
# Checkpoint saved!
# Episode #17100  |  Val. Score: +0.10   |  Avg. Val. Score: +0.13  |  Epsilon: 0.277
#                   Actor Loss: -0.880  |  Critic Loss: +0.162     |  Time Elapsed: 19489.66s
# Episode #17200  |  Val. Score: +0.60   |  Avg. Val. Score: +0.19  |  Epsilon: 0.275
#                   Actor Loss: -0.921  |  Critic Loss: +0.174     |  Time Elapsed: 19602.78s
# Episode #17300  |  Val. Score: +0.40   |  Avg. Val. Score: +0.26  |  Epsilon: 0.273
#                   Actor Loss: -0.928  |  Critic Loss: +0.173     |  Time Elapsed: 19721.72s
# Episode #17400  |  Val. Score: +0.40   |  Avg. Val. Score: +0.26  |  Epsilon: 0.271
#                   Actor Loss: -0.947  |  Critic Loss: +0.206     |  Time Elapsed: 19836.40s
# Episode #17500  |  Val. Score: +0.50   |  Avg. Val. Score: +0.29  |  Epsilon: 0.269
#                   Actor Loss: -0.944  |  Critic Loss: +0.204     |  Time Elapsed: 19956.90s
# Checkpoint saved!
# Episode #17600  |  Val. Score: +0.60   |  Avg. Val. Score: +0.35  |  Epsilon: 0.267
#                   Actor Loss: -0.925  |  Critic Loss: +0.181     |  Time Elapsed: 20076.55s
# Episode #17700  |  Val. Score: +0.30   |  Avg. Val. Score: +0.35  |  Epsilon: 0.265
#                   Actor Loss: -0.921  |  Critic Loss: +0.161     |  Time Elapsed: 20187.69s
# Episode #17800  |  Val. Score: +0.40   |  Avg. Val. Score: +0.36  |  Epsilon: 0.263
#                   Actor Loss: -0.861  |  Critic Loss: +0.159     |  Time Elapsed: 20301.06s
# Episode #17900  |  Val. Score: +0.60   |  Avg. Val. Score: +0.37  |  Epsilon: 0.261
#                   Actor Loss: -0.874  |  Critic Loss: +0.137     |  Time Elapsed: 20419.02s
# Episode #18000  |  Val. Score: -0.10   |  Avg. Val. Score: +0.38  |  Epsilon: 0.259
#                   Actor Loss: -0.802  |  Critic Loss: +0.185     |  Time Elapsed: 20532.54s
# Checkpoint saved!
# Episode #18100  |  Val. Score: +0.80   |  Avg. Val. Score: +0.45  |  Epsilon: 0.257
#                   Actor Loss: -0.829  |  Critic Loss: +0.151     |  Time Elapsed: 20651.48s
# Episode #18200  |  Val. Score: +0.50   |  Avg. Val. Score: +0.44  |  Epsilon: 0.255
#                   Actor Loss: -0.786  |  Critic Loss: +0.162     |  Time Elapsed: 20766.18s
# Episode #18300  |  Val. Score: +0.30   |  Avg. Val. Score: +0.43  |  Epsilon: 0.253
#                   Actor Loss: -0.755  |  Critic Loss: +0.145     |  Time Elapsed: 20877.85s
# Episode #18400  |  Val. Score: +0.50   |  Avg. Val. Score: +0.44  |  Epsilon: 0.252
#                   Actor Loss: -0.760  |  Critic Loss: +0.157     |  Time Elapsed: 20992.26s
# Episode #18500  |  Val. Score: -0.10   |  Avg. Val. Score: +0.38  |  Epsilon: 0.250
#                   Actor Loss: -0.761  |  Critic Loss: +0.124     |  Time Elapsed: 21104.77s
# Checkpoint saved!
# Episode #18600  |  Val. Score: +0.50   |  Avg. Val. Score: +0.37  |  Epsilon: 0.248
#                   Actor Loss: -0.765  |  Critic Loss: +0.128     |  Time Elapsed: 21222.33s
# Episode #18700  |  Val. Score: -0.20   |  Avg. Val. Score: +0.32  |  Epsilon: 0.246
#                   Actor Loss: -0.748  |  Critic Loss: +0.162     |  Time Elapsed: 21340.30s
# Episode #18800  |  Val. Score: +0.40   |  Avg. Val. Score: +0.32  |  Epsilon: 0.244
#                   Actor Loss: -0.797  |  Critic Loss: +0.137     |  Time Elapsed: 21461.32s
# Episode #18900  |  Val. Score: +0.20   |  Avg. Val. Score: +0.28  |  Epsilon: 0.242
#                   Actor Loss: -0.806  |  Critic Loss: +0.161     |  Time Elapsed: 21580.32s
# Episode #19000  |  Val. Score: +0.80   |  Avg. Val. Score: +0.37  |  Epsilon: 0.240
#                   Actor Loss: -0.794  |  Critic Loss: +0.156     |  Time Elapsed: 21699.65s
# Checkpoint saved!
# Episode #19100  |  Val. Score: +0.10   |  Avg. Val. Score: +0.30  |  Epsilon: 0.239
#                   Actor Loss: -0.779  |  Critic Loss: +0.129     |  Time Elapsed: 21819.00s
# Episode #19200  |  Val. Score: +1.00   |  Avg. Val. Score: +0.35  |  Epsilon: 0.237
#                   Actor Loss: -0.783  |  Critic Loss: +0.142     |  Time Elapsed: 21937.41s
# Episode #19300  |  Val. Score: +0.40   |  Avg. Val. Score: +0.36  |  Epsilon: 0.235
#                   Actor Loss: -0.786  |  Critic Loss: +0.148     |  Time Elapsed: 22047.72s
# Episode #19400  |  Val. Score: +0.40   |  Avg. Val. Score: +0.35  |  Epsilon: 0.233
#                   Actor Loss: -0.792  |  Critic Loss: +0.120     |  Time Elapsed: 22163.61s
# Episode #19500  |  Val. Score: +1.00   |  Avg. Val. Score: +0.46  |  Epsilon: 0.232
#                   Actor Loss: -0.732  |  Critic Loss: +0.149     |  Time Elapsed: 22283.15s
# Checkpoint saved!
# Episode #19600  |  Val. Score: +0.40   |  Avg. Val. Score: +0.45  |  Epsilon: 0.230
#                   Actor Loss: -0.726  |  Critic Loss: +0.134     |  Time Elapsed: 22399.13s
# Episode #19700  |  Val. Score: +0.20   |  Avg. Val. Score: +0.49  |  Epsilon: 0.228
#                   Actor Loss: -0.703  |  Critic Loss: +0.135     |  Time Elapsed: 22519.36s
# Episode #19800  |  Val. Score: +0.50   |  Avg. Val. Score: +0.50  |  Epsilon: 0.226
#                   Actor Loss: -0.722  |  Critic Loss: +0.121     |  Time Elapsed: 22639.69s
# Episode #19900  |  Val. Score: +0.40   |  Avg. Val. Score: +0.52  |  Epsilon: 0.225
#                   Actor Loss: -0.736  |  Critic Loss: +0.143     |  Time Elapsed: 22755.56s
# Episode #20000  |  Val. Score: +0.20   |  Avg. Val. Score: +0.46  |  Epsilon: 0.223
#                   Actor Loss: -0.742  |  Critic Loss: +0.127     |  Time Elapsed: 22876.05s
# Checkpoint saved!
# Animation of critic values saved!
# Episode #20100  |  Val. Score: -0.30   |  Avg. Val. Score: +0.42  |  Epsilon: 0.221
#                   Actor Loss: -0.727  |  Critic Loss: +0.130     |  Time Elapsed: 23006.68s
# Episode #20200  |  Val. Score: +0.00   |  Avg. Val. Score: +0.32  |  Epsilon: 0.220
#                   Actor Loss: -0.709  |  Critic Loss: +0.146     |  Time Elapsed: 23129.17s
# Episode #20300  |  Val. Score: +0.50   |  Avg. Val. Score: +0.33  |  Epsilon: 0.218
#                   Actor Loss: -0.695  |  Critic Loss: +0.135     |  Time Elapsed: 23243.69s
# Episode #20400  |  Val. Score: +0.60   |  Avg. Val. Score: +0.35  |  Epsilon: 0.217
#                   Actor Loss: -0.696  |  Critic Loss: +0.130     |  Time Elapsed: 23362.28s
# Episode #20500  |  Val. Score: +0.40   |  Avg. Val. Score: +0.29  |  Epsilon: 0.215
#                   Actor Loss: -0.716  |  Critic Loss: +0.132     |  Time Elapsed: 23476.63s
# Checkpoint saved!
# Episode #20600  |  Val. Score: +0.00   |  Avg. Val. Score: +0.25  |  Epsilon: 0.213
#                   Actor Loss: -0.736  |  Critic Loss: +0.143     |  Time Elapsed: 23593.12s
# Episode #20700  |  Val. Score: +0.20   |  Avg. Val. Score: +0.25  |  Epsilon: 0.212
#                   Actor Loss: -0.734  |  Critic Loss: +0.119     |  Time Elapsed: 23709.85s
# Episode #20800  |  Val. Score: +0.20   |  Avg. Val. Score: +0.22  |  Epsilon: 0.210
#                   Actor Loss: -0.720  |  Critic Loss: +0.138     |  Time Elapsed: 23825.00s
# Episode #20900  |  Val. Score: +0.30   |  Avg. Val. Score: +0.21  |  Epsilon: 0.209
#                   Actor Loss: -0.754  |  Critic Loss: +0.163     |  Time Elapsed: 23942.08s
# Episode #21000  |  Val. Score: +0.70   |  Avg. Val. Score: +0.26  |  Epsilon: 0.207
#                   Actor Loss: -0.788  |  Critic Loss: +0.145     |  Time Elapsed: 24058.28s
# Checkpoint saved!
# Episode #21100  |  Val. Score: +0.10   |  Avg. Val. Score: +0.30  |  Epsilon: 0.205
#                   Actor Loss: -0.773  |  Critic Loss: +0.138     |  Time Elapsed: 24176.30s
# Episode #21200  |  Val. Score: +0.80   |  Avg. Val. Score: +0.38  |  Epsilon: 0.204
#                   Actor Loss: -0.755  |  Critic Loss: +0.128     |  Time Elapsed: 24297.41s
# Episode #21300  |  Val. Score: +0.70   |  Avg. Val. Score: +0.40  |  Epsilon: 0.202
#                   Actor Loss: -0.702  |  Critic Loss: +0.127     |  Time Elapsed: 24415.59s
# Episode #21400  |  Val. Score: +0.40   |  Avg. Val. Score: +0.38  |  Epsilon: 0.201
#                   Actor Loss: -0.733  |  Critic Loss: +0.118     |  Time Elapsed: 24529.91s
# Episode #21500  |  Val. Score: +0.40   |  Avg. Val. Score: +0.38  |  Epsilon: 0.199
#                   Actor Loss: -0.708  |  Critic Loss: +0.123     |  Time Elapsed: 24647.76s
# Checkpoint saved!
# Episode #21600  |  Val. Score: +0.20   |  Avg. Val. Score: +0.40  |  Epsilon: 0.198
#                   Actor Loss: -0.693  |  Critic Loss: +0.145     |  Time Elapsed: 24766.91s
# Episode #21700  |  Val. Score: +0.50   |  Avg. Val. Score: +0.43  |  Epsilon: 0.196
#                   Actor Loss: -0.722  |  Critic Loss: +0.117     |  Time Elapsed: 24886.79s
# Episode #21800  |  Val. Score: +0.50   |  Avg. Val. Score: +0.46  |  Epsilon: 0.195
#                   Actor Loss: -0.708  |  Critic Loss: +0.124     |  Time Elapsed: 25006.16s
# Episode #21900  |  Val. Score: +0.20   |  Avg. Val. Score: +0.45  |  Epsilon: 0.193
#                   Actor Loss: -0.688  |  Critic Loss: +0.131     |  Time Elapsed: 25124.89s
# Episode #22000  |  Val. Score: +0.00   |  Avg. Val. Score: +0.38  |  Epsilon: 0.192
#                   Actor Loss: -0.730  |  Critic Loss: +0.122     |  Time Elapsed: 25243.94s
# Checkpoint saved!
# Episode #22100  |  Val. Score: +0.90   |  Avg. Val. Score: +0.46  |  Epsilon: 0.191
#                   Actor Loss: -0.691  |  Critic Loss: +0.128     |  Time Elapsed: 25365.09s
# Episode #22200  |  Val. Score: +0.60   |  Avg. Val. Score: +0.44  |  Epsilon: 0.189
#                   Actor Loss: -0.680  |  Critic Loss: +0.144     |  Time Elapsed: 25486.19s
# Episode #22300  |  Val. Score: +0.80   |  Avg. Val. Score: +0.45  |  Epsilon: 0.188
#                   Actor Loss: -0.687  |  Critic Loss: +0.141     |  Time Elapsed: 25604.93s
# Episode #22400  |  Val. Score: +0.70   |  Avg. Val. Score: +0.48  |  Epsilon: 0.186
#                   Actor Loss: -0.687  |  Critic Loss: +0.124     |  Time Elapsed: 25722.83s
# Episode #22500  |  Val. Score: +0.50   |  Avg. Val. Score: +0.49  |  Epsilon: 0.185
#                   Actor Loss: -0.692  |  Critic Loss: +0.118     |  Time Elapsed: 25844.52s
# Checkpoint saved!
# Episode #22600  |  Val. Score: +0.40   |  Avg. Val. Score: +0.51  |  Epsilon: 0.184
#                   Actor Loss: -0.682  |  Critic Loss: +0.122     |  Time Elapsed: 25967.84s
# Episode #22700  |  Val. Score: +0.70   |  Avg. Val. Score: +0.53  |  Epsilon: 0.182
#                   Actor Loss: -0.708  |  Critic Loss: +0.126     |  Time Elapsed: 26083.44s
# Episode #22800  |  Val. Score: +0.40   |  Avg. Val. Score: +0.52  |  Epsilon: 0.181
#                   Actor Loss: -0.694  |  Critic Loss: +0.126     |  Time Elapsed: 26202.72s
# Episode #22900  |  Val. Score: +0.20   |  Avg. Val. Score: +0.52  |  Epsilon: 0.180
#                   Actor Loss: -0.659  |  Critic Loss: +0.137     |  Time Elapsed: 26325.52s
# Episode #23000  |  Val. Score: +0.70   |  Avg. Val. Score: +0.59  |  Epsilon: 0.178
#                   Actor Loss: -0.693  |  Critic Loss: +0.127     |  Time Elapsed: 26445.60s
# Checkpoint saved!
# Episode #23100  |  Val. Score: +0.90   |  Avg. Val. Score: +0.59  |  Epsilon: 0.177
#                   Actor Loss: -0.654  |  Critic Loss: +0.116     |  Time Elapsed: 26568.83s
# Episode #23200  |  Val. Score: +0.80   |  Avg. Val. Score: +0.61  |  Epsilon: 0.176
#                   Actor Loss: -0.641  |  Critic Loss: +0.119     |  Time Elapsed: 26687.63s
# Episode #23300  |  Val. Score: -0.10   |  Avg. Val. Score: +0.52  |  Epsilon: 0.174
#                   Actor Loss: -0.642  |  Critic Loss: +0.123     |  Time Elapsed: 26805.20s
# Episode #23400  |  Val. Score: +0.60   |  Avg. Val. Score: +0.51  |  Epsilon: 0.173
#                   Actor Loss: -0.647  |  Critic Loss: +0.139     |  Time Elapsed: 26923.90s
# Episode #23500  |  Val. Score: +0.20   |  Avg. Val. Score: +0.48  |  Epsilon: 0.172
#                   Actor Loss: -0.674  |  Critic Loss: +0.127     |  Time Elapsed: 27042.61s
# Checkpoint saved!
# Episode #23600  |  Val. Score: +0.60   |  Avg. Val. Score: +0.50  |  Epsilon: 0.170
#                   Actor Loss: -0.676  |  Critic Loss: +0.140     |  Time Elapsed: 27162.08s
# Episode #23700  |  Val. Score: +0.60   |  Avg. Val. Score: +0.49  |  Epsilon: 0.169
#                   Actor Loss: -0.691  |  Critic Loss: +0.117     |  Time Elapsed: 27283.76s
# Episode #23800  |  Val. Score: +0.80   |  Avg. Val. Score: +0.53  |  Epsilon: 0.168
#                   Actor Loss: -0.676  |  Critic Loss: +0.128     |  Time Elapsed: 27403.26s
# Episode #23900  |  Val. Score: -0.20   |  Avg. Val. Score: +0.49  |  Epsilon: 0.167
#                   Actor Loss: -0.689  |  Critic Loss: +0.131     |  Time Elapsed: 27525.88s
# Episode #24000  |  Val. Score: +0.50   |  Avg. Val. Score: +0.47  |  Epsilon: 0.165
#                   Actor Loss: -0.653  |  Critic Loss: +0.138     |  Time Elapsed: 27647.04s
# Checkpoint saved!
# Episode #24100  |  Val. Score: +0.90   |  Avg. Val. Score: +0.47  |  Epsilon: 0.164
#                   Actor Loss: -0.663  |  Critic Loss: +0.135     |  Time Elapsed: 27766.55s
# Episode #24200  |  Val. Score: +0.40   |  Avg. Val. Score: +0.43  |  Epsilon: 0.163
#                   Actor Loss: -0.652  |  Critic Loss: +0.133     |  Time Elapsed: 27887.75s
# Episode #24300  |  Val. Score: +0.40   |  Avg. Val. Score: +0.48  |  Epsilon: 0.162
#                   Actor Loss: -0.664  |  Critic Loss: +0.103     |  Time Elapsed: 28007.44s
# Episode #24400  |  Val. Score: +0.40   |  Avg. Val. Score: +0.46  |  Epsilon: 0.160
#                   Actor Loss: -0.664  |  Critic Loss: +0.126     |  Time Elapsed: 28126.59s
# Episode #24500  |  Val. Score: +0.30   |  Avg. Val. Score: +0.47  |  Epsilon: 0.159
#                   Actor Loss: -0.652  |  Critic Loss: +0.141     |  Time Elapsed: 28246.99s
# Checkpoint saved!
# Episode #24600  |  Val. Score: +1.00   |  Avg. Val. Score: +0.51  |  Epsilon: 0.158
#                   Actor Loss: -0.702  |  Critic Loss: +0.126     |  Time Elapsed: 28366.74s
# Episode #24700  |  Val. Score: +0.70   |  Avg. Val. Score: +0.52  |  Epsilon: 0.157
#                   Actor Loss: -0.696  |  Critic Loss: +0.133     |  Time Elapsed: 28493.51s
# Episode #24800  |  Val. Score: +0.20   |  Avg. Val. Score: +0.46  |  Epsilon: 0.156
#                   Actor Loss: -0.702  |  Critic Loss: +0.122     |  Time Elapsed: 28615.11s
# Episode #24900  |  Val. Score: +0.70   |  Avg. Val. Score: +0.55  |  Epsilon: 0.154
#                   Actor Loss: -0.684  |  Critic Loss: +0.147     |  Time Elapsed: 28743.30s
# Episode #25000  |  Val. Score: +0.50   |  Avg. Val. Score: +0.55  |  Epsilon: 0.153
#                   Actor Loss: -0.677  |  Critic Loss: +0.133     |  Time Elapsed: 28868.20s
# Checkpoint saved!
# Animation of critic values saved!
# Episode #25100  |  Val. Score: +0.20   |  Avg. Val. Score: +0.48  |  Epsilon: 0.152
#                   Actor Loss: -0.678  |  Critic Loss: +0.131     |  Time Elapsed: 29006.44s
# Episode #25200  |  Val. Score: +0.80   |  Avg. Val. Score: +0.52  |  Epsilon: 0.151
#                   Actor Loss: -0.708  |  Critic Loss: +0.132     |  Time Elapsed: 29132.62s
# Episode #25300  |  Val. Score: +0.40   |  Avg. Val. Score: +0.52  |  Epsilon: 0.150
#                   Actor Loss: -0.691  |  Critic Loss: +0.131     |  Time Elapsed: 29258.61s
# Episode #25400  |  Val. Score: +0.60   |  Avg. Val. Score: +0.54  |  Epsilon: 0.149
#                   Actor Loss: -0.705  |  Critic Loss: +0.143     |  Time Elapsed: 29380.99s
# Episode #25500  |  Val. Score: +0.60   |  Avg. Val. Score: +0.57  |  Epsilon: 0.148
#                   Actor Loss: -0.698  |  Critic Loss: +0.126     |  Time Elapsed: 29506.54s
# Checkpoint saved!
# Episode #25600  |  Val. Score: +0.50   |  Avg. Val. Score: +0.52  |  Epsilon: 0.147
#                   Actor Loss: -0.700  |  Critic Loss: +0.130     |  Time Elapsed: 29635.58s
# Episode #25700  |  Val. Score: +0.20   |  Avg. Val. Score: +0.47  |  Epsilon: 0.146
#                   Actor Loss: -0.694  |  Critic Loss: +0.131     |  Time Elapsed: 29762.71s
# Episode #25800  |  Val. Score: +0.70   |  Avg. Val. Score: +0.52  |  Epsilon: 0.144
#                   Actor Loss: -0.671  |  Critic Loss: +0.128     |  Time Elapsed: 29886.74s
# Episode #25900  |  Val. Score: +0.60   |  Avg. Val. Score: +0.51  |  Epsilon: 0.143
#                   Actor Loss: -0.662  |  Critic Loss: +0.124     |  Time Elapsed: 30013.65s
# Episode #26000  |  Val. Score: +0.70   |  Avg. Val. Score: +0.53  |  Epsilon: 0.142
#                   Actor Loss: -0.664  |  Critic Loss: +0.120     |  Time Elapsed: 30140.65s
# Checkpoint saved!
# Episode #26100  |  Val. Score: +0.70   |  Avg. Val. Score: +0.58  |  Epsilon: 0.141
#                   Actor Loss: -0.634  |  Critic Loss: +0.116     |  Time Elapsed: 30267.17s
# Episode #26200  |  Val. Score: +0.50   |  Avg. Val. Score: +0.55  |  Epsilon: 0.140
#                   Actor Loss: -0.623  |  Critic Loss: +0.135     |  Time Elapsed: 30387.81s
# Episode #26300  |  Val. Score: +0.70   |  Avg. Val. Score: +0.58  |  Epsilon: 0.139
#                   Actor Loss: -0.684  |  Critic Loss: +0.118     |  Time Elapsed: 30507.91s
# Episode #26400  |  Val. Score: +0.60   |  Avg. Val. Score: +0.58  |  Epsilon: 0.138
#                   Actor Loss: -0.659  |  Critic Loss: +0.128     |  Time Elapsed: 30626.92s
# Episode #26500  |  Val. Score: +0.70   |  Avg. Val. Score: +0.59  |  Epsilon: 0.137
#                   Actor Loss: -0.674  |  Critic Loss: +0.108     |  Time Elapsed: 30747.38s
# Checkpoint saved!
# Episode #26600  |  Val. Score: +0.40   |  Avg. Val. Score: +0.58  |  Epsilon: 0.136
#                   Actor Loss: -0.670  |  Critic Loss: +0.110     |  Time Elapsed: 30867.83s
# Episode #26700  |  Val. Score: +0.70   |  Avg. Val. Score: +0.63  |  Epsilon: 0.135
#                   Actor Loss: -0.662  |  Critic Loss: +0.131     |  Time Elapsed: 30990.53s
# ...
# Episode #91300  |  Val. Score: +0.80   |  Avg. Val. Score: +0.81  |  Epsilon: 0.010
#                   Actor Loss: -0.721  |  Critic Loss: +0.142     |  Time Elapsed: 139131.61s
# Episode #91400  |  Val. Score: +0.50   |  Avg. Val. Score: +0.77  |  Epsilon: 0.010
#                   Actor Loss: -0.696  |  Critic Loss: +0.144     |  Time Elapsed: 139300.72s
# Episode #91500  |  Val. Score: +1.00   |  Avg. Val. Score: +0.78  |  Epsilon: 0.010
#                   Actor Loss: -0.721  |  Critic Loss: +0.145     |  Time Elapsed: 139475.63s
# Checkpoint saved!
# Episode #91600  |  Val. Score: +0.50   |  Avg. Val. Score: +0.75  |  Epsilon: 0.010
#                   Actor Loss: -0.688  |  Critic Loss: +0.152     |  Time Elapsed: 139649.45s
# Episode #91700  |  Val. Score: +1.00   |  Avg. Val. Score: +0.79  |  Epsilon: 0.010
#                   Actor Loss: -0.687  |  Critic Loss: +0.137     |  Time Elapsed: 139820.24s
# Episode #91800  |  Val. Score: +0.60   |  Avg. Val. Score: +0.77  |  Epsilon: 0.010
#                   Actor Loss: -0.671  |  Critic Loss: +0.138     |  Time Elapsed: 139985.19s
# Episode #91900  |  Val. Score: +0.80   |  Avg. Val. Score: +0.78  |  Epsilon: 0.010
#                   Actor Loss: -0.674  |  Critic Loss: +0.110     |  Time Elapsed: 140153.95s
# Episode #92000  |  Val. Score: +0.60   |  Avg. Val. Score: +0.76  |  Epsilon: 0.010
#                   Actor Loss: -0.676  |  Critic Loss: +0.162     |  Time Elapsed: 140323.10s
# Checkpoint saved!
# Episode #92100  |  Val. Score: +0.80   |  Avg. Val. Score: +0.74  |  Epsilon: 0.010
#                   Actor Loss: -0.689  |  Critic Loss: +0.153     |  Time Elapsed: 140494.17s
# Episode #92200  |  Val. Score: +0.80   |  Avg. Val. Score: +0.74  |  Epsilon: 0.010
#                   Actor Loss: -0.699  |  Critic Loss: +0.122     |  Time Elapsed: 140659.93s
# Episode #92300  |  Val. Score: +0.60   |  Avg. Val. Score: +0.72  |  Epsilon: 0.010
#                   Actor Loss: -0.692  |  Critic Loss: +0.139     |  Time Elapsed: 140828.10s
# Episode #92400  |  Val. Score: +1.00   |  Avg. Val. Score: +0.77  |  Epsilon: 0.010
#                   Actor Loss: -0.709  |  Critic Loss: +0.136     |  Time Elapsed: 140994.56s
# Episode #92500  |  Val. Score: +0.80   |  Avg. Val. Score: +0.75  |  Epsilon: 0.010
#                   Actor Loss: -0.689  |  Critic Loss: +0.133     |  Time Elapsed: 141160.94s
# Checkpoint saved!
# Episode #92600  |  Val. Score: +0.40   |  Avg. Val. Score: +0.74  |  Epsilon: 0.010
#                   Actor Loss: -0.690  |  Critic Loss: +0.132     |  Time Elapsed: 141328.51s
# Episode #92700  |  Val. Score: +1.00   |  Avg. Val. Score: +0.74  |  Epsilon: 0.010
#                   Actor Loss: -0.703  |  Critic Loss: +0.124     |  Time Elapsed: 141490.78s
# Episode #92800  |  Val. Score: +1.00   |  Avg. Val. Score: +0.78  |  Epsilon: 0.010
#                   Actor Loss: -0.667  |  Critic Loss: +0.143     |  Time Elapsed: 141656.01s
# Episode #92900  |  Val. Score: +1.00   |  Avg. Val. Score: +0.80  |  Epsilon: 0.010
#                   Actor Loss: -0.655  |  Critic Loss: +0.129     |  Time Elapsed: 141817.65s
# Episode #93000  |  Val. Score: +1.00   |  Avg. Val. Score: +0.84  |  Epsilon: 0.010
#                   Actor Loss: -0.656  |  Critic Loss: +0.136     |  Time Elapsed: 141983.68s
# Checkpoint saved!
# Episode #93100  |  Val. Score: +1.00   |  Avg. Val. Score: +0.86  |  Epsilon: 0.010
#                   Actor Loss: -0.650  |  Critic Loss: +0.141     |  Time Elapsed: 142145.75s
# Episode #93200  |  Val. Score: +1.00   |  Avg. Val. Score: +0.88  |  Epsilon: 0.010
#                   Actor Loss: -0.663  |  Critic Loss: +0.142     |  Time Elapsed: 142303.35s
# Episode #93300  |  Val. Score: +0.60   |  Avg. Val. Score: +0.88  |  Epsilon: 0.010
#                   Actor Loss: -0.653  |  Critic Loss: +0.128     |  Time Elapsed: 142465.61s
# Episode #93400  |  Val. Score: +1.00   |  Avg. Val. Score: +0.88  |  Epsilon: 0.010
#                   Actor Loss: -0.640  |  Critic Loss: +0.136     |  Time Elapsed: 142626.84s
# Episode #93500  |  Val. Score: +1.00   |  Avg. Val. Score: +0.90  |  Epsilon: 0.010
#                   Actor Loss: -0.650  |  Critic Loss: +0.134     |  Time Elapsed: 142788.50s
# Checkpoint saved!
# Episode #93600  |  Val. Score: +0.50   |  Avg. Val. Score: +0.91  |  Epsilon: 0.010
#                   Actor Loss: -0.635  |  Critic Loss: +0.144     |  Time Elapsed: 142957.74s
# Episode #93700  |  Val. Score: +0.70   |  Avg. Val. Score: +0.88  |  Epsilon: 0.010
#                   Actor Loss: -0.642  |  Critic Loss: +0.132     |  Time Elapsed: 143123.39s
# Episode #93800  |  Val. Score: +0.70   |  Avg. Val. Score: +0.85  |  Epsilon: 0.010
#                   Actor Loss: -0.647  |  Critic Loss: +0.130     |  Time Elapsed: 143289.44s
# Episode #93900  |  Val. Score: +0.70   |  Avg. Val. Score: +0.82  |  Epsilon: 0.010
#                   Actor Loss: -0.632  |  Critic Loss: +0.138     |  Time Elapsed: 143451.87s
# Episode #94000  |  Val. Score: +0.80   |  Avg. Val. Score: +0.80  |  Epsilon: 0.010
#                   Actor Loss: -0.643  |  Critic Loss: +0.133     |  Time Elapsed: 143610.20s
# Checkpoint saved!
# Episode #94100  |  Val. Score: +0.80   |  Avg. Val. Score: +0.78  |  Epsilon: 0.010
#                   Actor Loss: -0.631  |  Critic Loss: +0.130     |  Time Elapsed: 143774.44s
# Episode #94200  |  Val. Score: +0.80   |  Avg. Val. Score: +0.76  |  Epsilon: 0.010
#                   Actor Loss: -0.645  |  Critic Loss: +0.135     |  Time Elapsed: 143940.91s
# Episode #94300  |  Val. Score: +0.60   |  Avg. Val. Score: +0.76  |  Epsilon: 0.010
#                   Actor Loss: -0.648  |  Critic Loss: +0.131     |  Time Elapsed: 144100.16s
# Episode #94400  |  Val. Score: +1.00   |  Avg. Val. Score: +0.76  |  Epsilon: 0.010
#                   Actor Loss: -0.639  |  Critic Loss: +0.128     |  Time Elapsed: 144265.21s
# Episode #94500  |  Val. Score: +1.00   |  Avg. Val. Score: +0.76  |  Epsilon: 0.010
#                   Actor Loss: -0.652  |  Critic Loss: +0.143     |  Time Elapsed: 144436.87s
# Checkpoint saved!
# Episode #94600  |  Val. Score: +0.80   |  Avg. Val. Score: +0.79  |  Epsilon: 0.010
#                   Actor Loss: -0.631  |  Critic Loss: +0.135     |  Time Elapsed: 144602.99s
# Episode #94700  |  Val. Score: +0.80   |  Avg. Val. Score: +0.80  |  Epsilon: 0.010
#                   Actor Loss: -0.644  |  Critic Loss: +0.136     |  Time Elapsed: 144763.48s
# Episode #94800  |  Val. Score: +1.00   |  Avg. Val. Score: +0.83  |  Epsilon: 0.010
#                   Actor Loss: -0.637  |  Critic Loss: +0.131     |  Time Elapsed: 144928.34s
# Episode #94900  |  Val. Score: +1.00   |  Avg. Val. Score: +0.86  |  Epsilon: 0.010
#                   Actor Loss: -0.624  |  Critic Loss: +0.125     |  Time Elapsed: 145091.19s
# Episode #95000  |  Val. Score: +0.80   |  Avg. Val. Score: +0.86  |  Epsilon: 0.010
#                   Actor Loss: -0.655  |  Critic Loss: +0.141     |  Time Elapsed: 145265.53s
# Checkpoint saved!
# Animation of critic values saved!
# Episode #95100  |  Val. Score: +0.60   |  Avg. Val. Score: +0.84  |  Epsilon: 0.010
#                   Actor Loss: -0.699  |  Critic Loss: +0.142     |  Time Elapsed: 145483.69s
# Episode #95200  |  Val. Score: +1.00   |  Avg. Val. Score: +0.86  |  Epsilon: 0.010
#                   Actor Loss: -0.683  |  Critic Loss: +0.132     |  Time Elapsed: 145661.36s
# Episode #95300  |  Val. Score: +0.40   |  Avg. Val. Score: +0.84  |  Epsilon: 0.010
#                   Actor Loss: -0.671  |  Critic Loss: +0.147     |  Time Elapsed: 145835.06s
# Episode #95400  |  Val. Score: +0.70   |  Avg. Val. Score: +0.81  |  Epsilon: 0.010
#                   Actor Loss: -0.712  |  Critic Loss: +0.124     |  Time Elapsed: 146012.20s
# Episode #95500  |  Val. Score: +0.70   |  Avg. Val. Score: +0.78  |  Epsilon: 0.010
#                   Actor Loss: -0.688  |  Critic Loss: +0.145     |  Time Elapsed: 146183.26s
# Checkpoint saved!
# Episode #95600  |  Val. Score: +1.00   |  Avg. Val. Score: +0.80  |  Epsilon: 0.010
#                   Actor Loss: -0.693  |  Critic Loss: +0.135     |  Time Elapsed: 146353.29s
# Episode #95700  |  Val. Score: +0.80   |  Avg. Val. Score: +0.80  |  Epsilon: 0.010
#                   Actor Loss: -0.681  |  Critic Loss: +0.139     |  Time Elapsed: 146526.01s
# Episode #95800  |  Val. Score: +0.20   |  Avg. Val. Score: +0.72  |  Epsilon: 0.010
#                   Actor Loss: -0.681  |  Critic Loss: +0.134     |  Time Elapsed: 146699.99s
# Episode #95900  |  Val. Score: +1.00   |  Avg. Val. Score: +0.72  |  Epsilon: 0.010
#                   Actor Loss: -0.653  |  Critic Loss: +0.141     |  Time Elapsed: 146869.01s
# Episode #96000  |  Val. Score: +1.00   |  Avg. Val. Score: +0.74  |  Epsilon: 0.010
#                   Actor Loss: -0.658  |  Critic Loss: +0.149     |  Time Elapsed: 147042.80s
# Checkpoint saved!
# Episode #96100  |  Val. Score: +0.70   |  Avg. Val. Score: +0.75  |  Epsilon: 0.010
#                   Actor Loss: -0.664  |  Critic Loss: +0.146     |  Time Elapsed: 147212.34s
# Episode #96200  |  Val. Score: +1.00   |  Avg. Val. Score: +0.75  |  Epsilon: 0.010
#                   Actor Loss: -0.673  |  Critic Loss: +0.121     |  Time Elapsed: 147388.74s
# Episode #96300  |  Val. Score: +0.60   |  Avg. Val. Score: +0.77  |  Epsilon: 0.010
#                   Actor Loss: -0.651  |  Critic Loss: +0.125     |  Time Elapsed: 147561.48s
# Episode #96400  |  Val. Score: +0.80   |  Avg. Val. Score: +0.78  |  Epsilon: 0.010
#                   Actor Loss: -0.675  |  Critic Loss: +0.130     |  Time Elapsed: 147733.11s
# Episode #96500  |  Val. Score: +1.00   |  Avg. Val. Score: +0.81  |  Epsilon: 0.010
#                   Actor Loss: -0.637  |  Critic Loss: +0.143     |  Time Elapsed: 147906.35s
# Checkpoint saved!
# Episode #96600  |  Val. Score: +0.80   |  Avg. Val. Score: +0.79  |  Epsilon: 0.010
#                   Actor Loss: -0.651  |  Critic Loss: +0.136     |  Time Elapsed: 148066.89s
# Episode #96700  |  Val. Score: +1.00   |  Avg. Val. Score: +0.81  |  Epsilon: 0.010
#                   Actor Loss: -0.674  |  Critic Loss: +0.123     |  Time Elapsed: 148228.47s
# Episode #96800  |  Val. Score: +1.00   |  Avg. Val. Score: +0.89  |  Epsilon: 0.010
#                   Actor Loss: -0.675  |  Critic Loss: +0.123     |  Time Elapsed: 148387.08s
# Episode #96900  |  Val. Score: +0.70   |  Avg. Val. Score: +0.86  |  Epsilon: 0.010
#                   Actor Loss: -0.653  |  Critic Loss: +0.134     |  Time Elapsed: 148544.41s
# Episode #97000  |  Val. Score: +0.60   |  Avg. Val. Score: +0.82  |  Epsilon: 0.010
#                   Actor Loss: -0.648  |  Critic Loss: +0.144     |  Time Elapsed: 148702.64s
# Checkpoint saved!
# Episode #97100  |  Val. Score: +0.80   |  Avg. Val. Score: +0.83  |  Epsilon: 0.010
#                   Actor Loss: -0.656  |  Critic Loss: +0.125     |  Time Elapsed: 148871.53s
# Episode #97200  |  Val. Score: +1.00   |  Avg. Val. Score: +0.83  |  Epsilon: 0.010
#                   Actor Loss: -0.673  |  Critic Loss: +0.135     |  Time Elapsed: 149038.47s
# Episode #97300  |  Val. Score: +0.60   |  Avg. Val. Score: +0.83  |  Epsilon: 0.010
#                   Actor Loss: -0.668  |  Critic Loss: +0.142     |  Time Elapsed: 149205.70s
# Episode #97400  |  Val. Score: +1.00   |  Avg. Val. Score: +0.85  |  Epsilon: 0.010
#                   Actor Loss: -0.640  |  Critic Loss: +0.129     |  Time Elapsed: 149378.82s
# Episode #97500  |  Val. Score: +0.60   |  Avg. Val. Score: +0.81  |  Epsilon: 0.010
#                   Actor Loss: -0.641  |  Critic Loss: +0.138     |  Time Elapsed: 149552.43s
# Checkpoint saved!
# Episode #97600  |  Val. Score: +0.60   |  Avg. Val. Score: +0.79  |  Epsilon: 0.010
#                   Actor Loss: -0.658  |  Critic Loss: +0.137     |  Time Elapsed: 149719.62s
# Episode #97700  |  Val. Score: +1.00   |  Avg. Val. Score: +0.79  |  Epsilon: 0.010
#                   Actor Loss: -0.649  |  Critic Loss: +0.143     |  Time Elapsed: 149885.14s
# Episode #97800  |  Val. Score: +0.70   |  Avg. Val. Score: +0.76  |  Epsilon: 0.010
#                   Actor Loss: -0.635  |  Critic Loss: +0.128     |  Time Elapsed: 150052.65s
# Episode #97900  |  Val. Score: +0.80   |  Avg. Val. Score: +0.77  |  Epsilon: 0.010
#                   Actor Loss: -0.635  |  Critic Loss: +0.124     |  Time Elapsed: 150227.99s
# Episode #98000  |  Val. Score: +1.00   |  Avg. Val. Score: +0.81  |  Epsilon: 0.010
#                   Actor Loss: -0.655  |  Critic Loss: +0.114     |  Time Elapsed: 150397.20s
# Checkpoint saved!
# Episode #98100  |  Val. Score: +0.50   |  Avg. Val. Score: +0.78  |  Epsilon: 0.010
#                   Actor Loss: -0.708  |  Critic Loss: +0.163     |  Time Elapsed: 150565.20s
# Episode #98200  |  Val. Score: +0.60   |  Avg. Val. Score: +0.74  |  Epsilon: 0.010
#                   Actor Loss: -0.742  |  Critic Loss: +0.148     |  Time Elapsed: 150734.10s
# Episode #98300  |  Val. Score: +0.20   |  Avg. Val. Score: +0.70  |  Epsilon: 0.010
#                   Actor Loss: -0.782  |  Critic Loss: +0.151     |  Time Elapsed: 150904.88s
# Episode #98400  |  Val. Score: +0.90   |  Avg. Val. Score: +0.69  |  Epsilon: 0.010
#                   Actor Loss: -0.779  |  Critic Loss: +0.151     |  Time Elapsed: 151083.26s
# Episode #98500  |  Val. Score: +1.00   |  Avg. Val. Score: +0.73  |  Epsilon: 0.010
#                   Actor Loss: -0.763  |  Critic Loss: +0.154     |  Time Elapsed: 151258.09s
# Checkpoint saved!
# Episode #98600  |  Val. Score: +0.80   |  Avg. Val. Score: +0.75  |  Epsilon: 0.010
#                   Actor Loss: -0.748  |  Critic Loss: +0.169     |  Time Elapsed: 151435.82s
# Episode #98700  |  Val. Score: +1.00   |  Avg. Val. Score: +0.75  |  Epsilon: 0.010
#                   Actor Loss: -0.751  |  Critic Loss: +0.162     |  Time Elapsed: 151618.59s
# Episode #98800  |  Val. Score: +0.80   |  Avg. Val. Score: +0.76  |  Epsilon: 0.010
#                   Actor Loss: -0.745  |  Critic Loss: +0.146     |  Time Elapsed: 151799.13s
# Episode #98900  |  Val. Score: +0.50   |  Avg. Val. Score: +0.73  |  Epsilon: 0.010
#                   Actor Loss: -0.738  |  Critic Loss: +0.146     |  Time Elapsed: 151972.98s
# Episode #99000  |  Val. Score: +1.00   |  Avg. Val. Score: +0.73  |  Epsilon: 0.010
#                   Actor Loss: -0.722  |  Critic Loss: +0.156     |  Time Elapsed: 152140.45s
# Checkpoint saved!
# Episode #99100  |  Val. Score: +1.00   |  Avg. Val. Score: +0.78  |  Epsilon: 0.010
#                   Actor Loss: -0.691  |  Critic Loss: +0.136     |  Time Elapsed: 152315.91s
# Episode #99200  |  Val. Score: +0.90   |  Avg. Val. Score: +0.81  |  Epsilon: 0.010
#                   Actor Loss: -0.710  |  Critic Loss: +0.133     |  Time Elapsed: 152494.38s
# Episode #99300  |  Val. Score: +0.90   |  Avg. Val. Score: +0.88  |  Epsilon: 0.010
#                   Actor Loss: -0.688  |  Critic Loss: +0.143     |  Time Elapsed: 152676.61s
# Episode #99400  |  Val. Score: +0.80   |  Avg. Val. Score: +0.87  |  Epsilon: 0.010
#                   Actor Loss: -0.689  |  Critic Loss: +0.126     |  Time Elapsed: 152851.78s
# Episode #99500  |  Val. Score: +0.60   |  Avg. Val. Score: +0.83  |  Epsilon: 0.010
#                   Actor Loss: -0.659  |  Critic Loss: +0.148     |  Time Elapsed: 153026.34s
# Checkpoint saved!
# Episode #99600  |  Val. Score: +0.70   |  Avg. Val. Score: +0.82  |  Epsilon: 0.010
#                   Actor Loss: -0.691  |  Critic Loss: +0.155     |  Time Elapsed: 153196.48s
# Episode #99700  |  Val. Score: +1.00   |  Avg. Val. Score: +0.82  |  Epsilon: 0.010
#                   Actor Loss: -0.681  |  Critic Loss: +0.152     |  Time Elapsed: 153367.51s
# Episode #99800  |  Val. Score: +1.00   |  Avg. Val. Score: +0.84  |  Epsilon: 0.010
#                   Actor Loss: -0.674  |  Critic Loss: +0.171     |  Time Elapsed: 153540.11s
# Episode #99900  |  Val. Score: +0.80   |  Avg. Val. Score: +0.87  |  Epsilon: 0.010
#                   Actor Loss: -0.685  |  Critic Loss: +0.142     |  Time Elapsed: 153714.12s
# Episode #100000  |  Val. Score: +0.80   |  Avg. Val. Score: +0.85  |  Epsilon: 0.010
#                   Actor Loss: -0.690  |  Critic Loss: +0.136     |  Time Elapsed: 153896.60s
# Checkpoint saved!
# Animation of critic values saved!
# Model saved!

# %%
len(critic_values_by_episode)
# Out:
# 100

# %%
final_validation_scores = validation_scores
final_critic_values_by_episode = critic_values_by_episode

# %%
# # Continue training
# validation_scores_continued, critic_values_by_episode_continued = init_train(controller, players,
#                     start_epoch=10001, critic_values_by_episode=critic_values_by_episode, model_path=f'../checkpoints/{MODEL_VERSION}_model.pt',
#                     n_episodes=10000, checkpoint_each=checkpoint_each, validate_each=validate_each,
#                     n_episodes_validation=n_episodes_validation, save_animation_each=save_animation_each,
#                     save_critic_value_each=save_critic_value_each, eps_start=0.01, eps_end=eps_end, eps_decay=eps_decay)

# %%
# final_validation_scores += validation_scores_continued
# final_critic_values_by_episode += critic_values_by_episode_continued

# %%
plot_scores(final_validation_scores, validate_each)

# %%
drl_agent.save_model(f'../checkpoints/{MODEL_VERSION}_model_final.pt')

# %%
# Plot loss functions
losses = drl_agent.get_losses()
fig, ax = plt.subplots(figsize=(18,6))
ax.plot(losses['actor_losses'], label='actor_losses')
ax.plot(losses['critic_losses'], label='critic_losses')
ax.set_xlabel('No. of Agent moves')
ax.set_ylabel('Loss')
# ax.plot(list((critic_loss - actor_loss) for critic_loss, actor_loss in zip(losses['critic_losses'][:], losses['actor_losses'][:])), label='diff_losses')
plt.legend(loc='best')
plt.show();

# %%
controller.reset_game(drl_checkpoint_path=f'../checkpoints/{MODEL_VERSION}_model.pt')
# Out:
# Select one of the following players to be player 1
# 0 - ./models/players\drl_player.py
# 1 - ./models/players\human_player.py
# 2 - ./models/players\random_player.py
# 3 - ./models/players\semi_random_player.py
# Input desired player number: 0
# player_class.__name__ = DRLPlayer
# player_kwargs['initial_checkpoint_path'] = drl_checkpoint_path = ../checkpoints/v6_model.pt
# initial_checkpoint_path: ../checkpoints/v6_model.pt
# Select one of the following players to be player 2
# 0 - ./models/players\drl_player.py
# 1 - ./models/players\human_player.py
# 2 - ./models/players\random_player.py
# 3 - ./models/players\semi_random_player.py
# Input desired player number: 1
# player_class.__name__ = HumanPlayer
#                   1 | 2 | 3
#                  ---+---+---
#                   4 | 5 | 6
#                  ---+---+---
#                   7 | 8 | 9
# Player 1 (X): 100           Player 2 (O): 100
#
# Player 1 DRLPlayer(X) bidding...
# Player 2 HumanPlayer(O) bidding...
# 15
# Player 1 DRLPlayer(X) bid: 46  |  Player 2 HumanPlayer(O) bid: 15  |
# Player 1 DRLPlayer(X) won the bet
#                   1 | 2 | 3
#                  ---+---+---
#                   4 | 5 | 6
#                  ---+---+---
#                   7 | 8 | X
# Player 1 (X):  54           Player 2 (O): 146
#
# Player 1 DRLPlayer(X) bidding...
# Player 2 HumanPlayer(O) bidding...
# 15
# Player 1 DRLPlayer(X) bid: 7  |  Player 2 HumanPlayer(O) bid: 15  |
# Player 2 HumanPlayer(O) won the bet
# Move: 5
#                   1 | 2 | 3
#                  ---+---+---
#                   4 | O | 6
#                  ---+---+---
#                   7 | 8 | X
# Player 1 (X):  69           Player 2 (O): 131
#
# Player 1 DRLPlayer(X) bidding...
# Player 2 HumanPlayer(O) bidding...
# 12
# Player 1 DRLPlayer(X) bid: 35  |  Player 2 HumanPlayer(O) bid: 12  |
# Player 1 DRLPlayer(X) won the bet
#                   1 | 2 | X
#                  ---+---+---
#                   4 | O | 6
#                  ---+---+---
#                   7 | 8 | X
# Player 1 (X):  34           Player 2 (O): 166
#
# Player 1 DRLPlayer(X) bidding...
# Player 2 HumanPlayer(O) bidding...
# 35
# Player 1 DRLPlayer(X) bid: 34  |  Player 2 HumanPlayer(O) bid: 35  |
# Player 2 HumanPlayer(O) won the bet
# Move: 6
#                   1 | 2 | X
#                  ---+---+---
#                   4 | O | O
#                  ---+---+---
#                   7 | 8 | X
# Player 1 (X):  69           Player 2 (O): 131
#
# Player 1 DRLPlayer(X) bidding...
# Player 2 HumanPlayer(O) bidding...
# 69
# Player 1 DRLPlayer(X) bid: 33  |  Player 2 HumanPlayer(O) bid: 69  |
# Player 2 HumanPlayer(O) won the bet
# Move: 4
#                   1 | 2 | X
#                  ---+---+---
#                   O | O | O
#                  ---+---+---
#                   7 | 8 | X
# Player 1 (X): 138           Player 2 (O):  62
#
#
# Player 2 HumanPlayer(O) won

# %%
run_validation(players, 1000)
# Out:
# 0.849

# %%
run_validation_semi_random(players, 1000)
# Out:
# 0.57
